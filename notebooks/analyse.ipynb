# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('../results/parallel/results.csv')

# %%
df.columns
# Out:
# Index(['strategy', 'scenario_id', 'no_drones', 'drone_capacity',
#        'no_customers', 'no_clusters', 'Total Distribution Time',
#        'Drones Travel Distance', 'Trucks Travel Distance',
#        'Trucks In-Cluster time', 'Drones Active Time', 'Drone Utilization',
#        'avg_span_2', 'avg_span_3', 'avg_span_4', 'avg_nodropoffs_2',
#        'avg_nodropoffs_3', 'avg_nodropoffs_4', 'median_span_2',
#        'median_span_3', 'median_span_4', 'median_nodropoffs_2',
#        'median_nodropoffs_3', 'median_nodropoffs_4',
#        'The Number of Battery Swaps', 'Total Time to Deliver All Packages',
#        'Total Package Delivery Time', 'Total Customer Delivery Time',
#        'Average Customer Delivery Time', 'Average Package Delivery Time',
#        'Median Package Delivery Time', 'Median Customer Delivery Time',
#        'no_of_customers_with_1_package', 'no_of_customers_with_2_package',
#        'no_of_customers_with_3_package', 'no_of_customers_with_4_package'],
# ...

# %%
sns.barplot(data=df, x='no_drones', y='Median Customer Delivery Time', hue='strategy')
# Out:
# <Axes: xlabel='no_drones', ylabel='Median Customer Delivery Time'>

# %%
sns.barplot(data=df, x='drone_capacity', y='median_span_3', hue='strategy')
# Out:
# <Axes: xlabel='drone_capacity', ylabel='median_span_3'>
